# %%
# %load_ext autoreload
# %autoreload 2
from evaluate_livekt import test_livekt
# import importlib
# importlib.reload(evaluate_livekt)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test_livekt()
# Out:
# ../pykt-toolkit/data/codeforces24/CF-data.csv
# ---
# Evaluating model  LR
# Test AUC 0.5941575378195096 on 125 samples at time 5
# Test AUC 0.6257861635220126 on 125 samples at time 10
# Test AUC 0.701038961038961 on 125 samples at time 15
# Test AUC 0.5446127946127947 on 125 samples at time 20
# ---
# Evaluating model  GBM
# Test AUC 0.5302556077203964 on 125 samples at time 5
# Test AUC 0.5655136268343816 on 125 samples at time 10
# Test AUC 0.6394805194805194 on 125 samples at time 15
# Test AUC 0.5990460157126825 on 125 samples at time 20
# ---
# Evaluating model  PFN
# Test AUC 0.5968961919666145 on 125 samples at time 5
# Test AUC 0.6445230607966457 on 125 samples at time 10
# Test AUC 0.6697402597402597 on 125 samples at time 15
# Test AUC 0.5934343434343434 on 125 samples at time 20
# ---
# Evaluating model  ICL
# Test AUC 0.5717266562336984 on 125 samples at time 5
# Test AUC 0.6367924528301887 on 125 samples at time 10
# Test AUC 0.6805194805194805 on 125 samples at time 15
# Test AUC 0.564534231200898 on 125 samples at time 20
#            5         10        15        20
# LR   0.002636  0.005454  0.010492  0.019738
# GBM  0.121012  0.140854  0.240333  0.158953
# PFN  0.354462  0.251239  0.276667  0.325077
# ICL  0.355635  0.324972  0.374858  0.429000
# t          5         10        15        20
# LR   0.594158  0.625786  0.701039  0.544613
# GBM  0.530256  0.565514  0.639481  0.599046
# PFN  0.596896  0.644523  0.669740  0.593434
# ICL  0.571727  0.636792  0.680519  0.564534

# %%
from evaluate_livekt import test_traditional_kt

# %%
test_traditional_kt()
# Out:
# 20 dkt
# /users/profs/2022/jill-jenn.vie/pykt/liveKT/live_kt.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['attempt_nb'] = df.groupby('user_id').cumcount() + 1
# df.columns: Index(['uid', 'fold', 'is_repeat', 'questions', 'responses', 'concepts'], dtype='object')
# train+valid original interactions num: 49491, select num: 0, qs: 11566, cs: 137, seqnum: 3008
# dropnum: 0
# train+valid sequences interactions num: 49491, select num: 49491, qs: 11566, cs: 137, seqnum: 3008
# dropnum: 0
# original test interactions num: 11660, select num: 0, qs: 5523, cs: 113, seqnum: 583
# test sequences interactions num: 11660, select num: 11660, qs: 5523, cs: 113, seqnum: 583
# ====================
# original train+valid,49491,3008,0
# train+valid sequences,49491,3008,49491
# test original,11660,583,0
# test sequences,11660,583,11660
# 2026-03-27 10:23:34 - main - said: load config files.
# Start init data
# assist2009_livekt dkt {'assist2015': {'dpath': '../data/assist2015', 'num_q': 0, 'num_c': 100, 'input_type': ['concepts'], 'max_concepts': 1, 'min_seq_len': 3, 'maxlen': 200, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'train_valid_original_file_quelevel': 'train_valid_quelevel.csv', 'train_valid_file_quelevel': 'train_valid_sequences_quelevel.csv', 'test_file_quelevel': 'test_sequences_quelevel.csv', 'test_window_file_quelevel': 'test_window_sequences_quelevel.csv', 'test_original_file_quelevel': 'test_quelevel.csv'}, 'algebra2005': {'dpath': '../data/algebra2005', 'num_q': 173113, 'num_c': 112, 'input_type': ['questions', 'concepts'], 'max_concepts': 7, 'min_seq_len': 3, 'maxlen': 200, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv', 'train_valid_original_file_quelevel': 'train_valid_quelevel.csv', 'train_valid_file_quelevel': 'train_valid_sequences_quelevel.csv', 'test_file_quelevel': 'test_sequences_quelevel.csv', 'test_window_file_quelevel': 'test_window_sequences_quelevel.csv', 'test_original_file_quelevel': 'test_quelevel.csv'}, 'assist2009': {'dpath': '../data/assist2009', 'num_q': 17737, 'num_c': 123, 'input_type': ['questions', 'concepts'], 'max_concepts': 4, 'min_seq_len': 3, 'maxlen': 200, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv', 'train_valid_original_file_quelevel': 'train_valid_quelevel.csv', 'train_valid_file_quelevel': 'train_valid_sequences_quelevel.csv', 'test_file_quelevel': 'test_sequences_quelevel.csv', 'test_window_file_quelevel': 'test_window_sequences_quelevel.csv', 'test_original_file_quelevel': 'test_quelevel.csv'}, 'slepemapy': {'dpath': '../data/slepemapy', 'num_q': 2913, 'num_c': 1458, 'input_type': ['questions', 'concepts'], 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv'}, 'assist2017': {'dpath': '../data/assist2017', 'num_q': 3162, 'num_c': 102, 'input_type': ['questions', 'concepts'], 'min_seq_len': 3, 'maxlen': 500, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv'}, 'assist2012': {'dpath': '../data/assist2012', 'num_q': 53070, 'num_c': 265, 'input_type': ['questions', 'concepts'], 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv'}, 'statics2011': {'dpath': '../data/static ...
# 2026-03-27 10:23:34 - main - said: init_dataset
# dataset_name:assist2009_livekt
# data_config:{'assist2015': {'dpath': '../data/assist2015', 'num_q': 0, 'num_c': 100, 'input_type': ['concepts'], 'max_concepts': 1, 'min_seq_len': 3, 'maxlen': 200, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'train_valid_original_file_quelevel': 'train_valid_quelevel.csv', 'train_valid_file_quelevel': 'train_valid_sequences_quelevel.csv', 'test_file_quelevel': 'test_sequences_quelevel.csv', 'test_window_file_quelevel': 'test_window_sequences_quelevel.csv', 'test_original_file_quelevel': 'test_quelevel.csv'}, 'algebra2005': {'dpath': '../data/algebra2005', 'num_q': 173113, 'num_c': 112, 'input_type': ['questions', 'concepts'], 'max_concepts': 7, 'min_seq_len': 3, 'maxlen': 200, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv', 'train_valid_original_file_quelevel': 'train_valid_quelevel.csv', 'train_valid_file_quelevel': 'train_valid_sequences_quelevel.csv', 'test_file_quelevel': 'test_sequences_quelevel.csv', 'test_window_file_quelevel': 'test_window_sequences_quelevel.csv', 'test_original_file_quelevel': 'test_quelevel.csv'}, 'assist2009': {'dpath': '../data/assist2009', 'num_q': 17737, 'num_c': 123, 'input_type': ['questions', 'concepts'], 'max_concepts': 4, 'min_seq_len': 3, 'maxlen': 200, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv', 'train_valid_original_file_quelevel': 'train_valid_quelevel.csv', 'train_valid_file_quelevel': 'train_valid_sequences_quelevel.csv', 'test_file_quelevel': 'test_sequences_quelevel.csv', 'test_window_file_quelevel': 'test_window_sequences_quelevel.csv', 'test_original_file_quelevel': 'test_quelevel.csv'}, 'slepemapy': {'dpath': '../data/slepemapy', 'num_q': 2913, 'num_c': 1458, 'input_type': ['questions', 'concepts'], 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv'}, 'assist2017': {'dpath': '../data/assist2017', 'num_q': 3162, 'num_c': 102, 'input_type': ['questions', 'concepts'], 'min_seq_len': 3, 'maxlen': 500, 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv'}, 'assist2012': {'dpath': '../data/assist2012', 'num_q': 53070, 'num_c': 265, 'input_type': ['questions', 'concepts'], 'emb_path': '', 'train_valid_original_file': 'train_valid.csv', 'train_valid_file': 'train_valid_sequences.csv', 'folds': [0, 1, 2, 3, 4], 'test_original_file': 'test.csv', 'test_file': 'test_sequences.csv', 'test_window_file': 'test_window_sequences.csv', 'test_question_file': 'test_question_sequences.csv', 'test_question_window_file': 'test_question_window_sequences.csv'}, 'statics2011': {'dpath': '../data/statics2011', 'n ...
# Start preprocessing ../data/assist2009_livekt/train_valid_sequences.csv fold: _0...
# interaction_num: 9927
# file path: ../data/assist2009_livekt/train_valid_sequences.csv, qlen: 602, clen: 602, rlen: 602
# Start preprocessing ../data/assist2009_livekt/train_valid_sequences.csv fold: _1_2_3_4...
# /users/profs/2022/jill-jenn.vie/pykt/liveKT/pykt/datasets/data_loader.py:151: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   dori[key] = LongTensor(dori[key])
# interaction_num: 39564
# file path: ../data/assist2009_livekt/train_valid_sequences.csv, qlen: 2406, clen: 2406, rlen: 2406
# params: {'dataset_name': 'assist2009_livekt', 'model_name': 'dkt', 'emb_type': 'qid', 'save_dir': '/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model', 'seed': 3407, 'fold': 0, 'use_wandb': 0, 'add_uuid': 0, 'learning_rate': 0.001, 'emb_size': 200, 'dropout': 0.1}, params_str: assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
# Start training model: dkt, embtype: qid, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1, dataset_name: assist2009_livekt
# model_config: {'use_wandb': 0, 'add_uuid': 0, 'learning_rate': 0.001, 'emb_size': 200, 'dropout': 0.1}
# train_config: {'batch_size': 256, 'num_epochs': 115, 'optimizer': 'adam', 'seq_len': 200}
# 2026-03-27 10:23:34 - main - said: init_model
# model_name:dkt
# model is DKT(
#   (interaction_emb): Embedding(276, 200)
#   (lstm_layer): LSTM(200, 200, batch_first=True)
#   (dropout_layer): Dropout(p=0.1, inplace=False)
#   (out_layer): Linear(in_features=200, out_features=138, bias=True)
# )
# 2026-03-27 10:23:35 - main - said: train model
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 1, validauc: 0.6832, validacc: 0.6745, best epoch: 1, best auc: 0.6832, train loss: 0.6628097051647416, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 2, validauc: 0.6982, validacc: 0.6829, best epoch: 2, best auc: 0.6982, train loss: 0.6059681162823713, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 3, validauc: 0.7088, validacc: 0.6921, best epoch: 3, best auc: 0.7088, train loss: 0.586866915312141, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 4, validauc: 0.7175, validacc: 0.6972, best epoch: 4, best auc: 0.7175, train loss: 0.573713489802911, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 5, validauc: 0.7221, validacc: 0.6969, best epoch: 5, best auc: 0.7221, train loss: 0.5631243645208425, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 6, validauc: 0.7252, validacc: 0.6975, best epoch: 6, best auc: 0.7252, train loss: 0.5542878826353844, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 7, validauc: 0.7278, validacc: 0.6989, best epoch: 7, best auc: 0.7278, train loss: 0.5464537086579238, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 8, validauc: 0.7295, validacc: 0.7002, best epoch: 8, best auc: 0.7295, train loss: 0.5394278245096396, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 9, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5330566346340413, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 10, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5288676800182996, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 11, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5256689512109336, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 12, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5162079314616748, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 13, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5100873200351737, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 14, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5039840333959449, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 15, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.5036864324089466, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 16, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.49599819391868083, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 17, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.4908537886866653, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 18, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.48466107166152117, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# ts.shape: (9325,), ps.shape: (9325,)
# Epoch: 19, validauc: 0.7313, validacc: 0.7013, best epoch: 9, best auc: 0.7313, train loss: 0.4782799185425052, emb_type: qid, model: dkt, save_dir: /users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model/assist2009_livekt_dkt_qid_/users/profs/2022/jill-jenn.vie/pykt/liveKT/saved_model_3407_0_0_0_0.001_200_0.1
#             testauc: -1, testacc: -1, window_testauc: -1, window_testacc: -1
# fold	modelname	embtype	testauc	testacc	window_testauc	window_testacc	validauc	validacc	best_epoch
# 0	dkt	qid	-1	-1	-1	-1	0.7313210418950791	0.7013404825737265	9
# end:2026-03-27 10:23:40.723251
# Total training time: 6.2s (0.1 min)
