# %%
# %load_ext autoreload
# %autoreload 2
from evaluate_livekt import test_livekt
# import importlib
# importlib.reload(evaluate_livekt)

# %%
results = []
results_times = []
for i in range(5):
    res, res_t = test_livekt(i_fold=i)
    results.append(res)
    results_times.append(res_t)

# %%
(sum(results) / 5).round(3)

# %%
from evaluate_livekt import test_traditional_kt

# %%
# !ls ../../pykt-toolkit/data/assist2009/

# %%
test_traditional_kt(0)

# %%
test_traditional_kt(1)

# %%
test_traditional_kt(2)

# %%
test_traditional_kt(3)

# %%
test_traditional_kt(4)
